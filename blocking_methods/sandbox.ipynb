# %%
# %%bash
#
# openssl s_client -showcerts -connect admburla.ru:443
# Out:
# bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# depth=2 C = RU, O = The Ministry of Digital Development and Communications, CN = Russian Trusted Root CA
# verify error:num=19:self-signed certificate in certificate chain
# verify return:1
# depth=2 C = RU, O = The Ministry of Digital Development and Communications, CN = Russian Trusted Root CA
# verify return:1
# depth=1 C = RU, O = The Ministry of Digital Development and Communications, CN = Russian Trusted Sub CA
# verify return:1
# depth=0 C = RU, ST = \D0\90\D0\BB\D1\82\D0\B0\D0\B9\D1\81\D0\BA\D0\B8\D0\B9 \D0\BA\D1\80\D0\B0\D0\B9, L = \D0\91\D1\83\D1\80\D0\BB\D0\B0, O = \D0\90\D0\B4\D0\BC\D0\B8\D0\BD\D0\B8\D1\81\D1\82\D1\80\D0\B0\D1\86\D0\B8\D1\8F \D0\91\D1\83\D1\80\D0\BB\D0\B8\D0\BD\D1\81\D0\BA\D0\BE\D0\B3\D0\BE \D1\80\D0\B0\D0\B9\D0\BE\D0\BD\D0\B0 \D0\90\D0\BB\D1\82\D0\B0\D0\B9\D1\81\D0\BA\D0\BE\D0\B3\D0\BE \D0\BA\D1\80\D0\B0\D1\8F, CN = *.admburla.ru
# verify return:1
# CONNECTED(00000003)
# ---
# ...

# %%
# %%bash
#
# openssl s_client -showcerts -connect vk.com:443
# Out:
# bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# depth=2 OU = GlobalSign ECC Root CA - R5, O = GlobalSign, CN = GlobalSign
# verify return:1
# depth=1 C = BE, O = GlobalSign nv-sa, CN = GlobalSign ECC OV SSL CA 2018
# verify return:1
# depth=0 C = RU, ST = Saint Petersburg, L = Saint Petersburg, O = V Kontakte LLC, CN = *.vk.com
# verify return:1
# CONNECTED(00000003)
# ---
# Certificate chain
#  0 s:C = RU, ST = Saint Petersburg, L = Saint Petersburg, O = V Kontakte LLC, CN = *.vk.com
#    i:C = BE, O = GlobalSign nv-sa, CN = GlobalSign ECC OV SSL CA 2018
#    a:PKEY: id-ecPublicKey, 256 (bit); sigalg: ecdsa-with-SHA384
#    v:NotBefore: Feb 14 11:17:01 2024 GMT; NotAfter: Mar  2 11:51:08 2025 GMT
# -----BEGIN CERTIFICATE-----
# MIIFvDCCBUKgAwIBAgIMeaxddCChplDhre6TMAoGCCqGSM49BAMDMFAxCzAJBgNV
# BAYTAkJFMRkwFwYDVQQKExBHbG9iYWxTaWduIG52LXNhMSYwJAYDVQQDEx1HbG9i
# YWxTaWduIEVDQyBPViBTU0wgQ0EgMjAxODAeFw0yNDAyMTQxMTE3MDFaFw0yNTAz
# ...

# %%
# %%bash
#
# openssl s_client -showcerts -connect vk.com:443
# Out:
# bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# depth=2 OU = GlobalSign ECC Root CA - R5, O = GlobalSign, CN = GlobalSign
# verify return:1
# depth=1 C = BE, O = GlobalSign nv-sa, CN = GlobalSign ECC OV SSL CA 2018
# verify return:1
# depth=0 C = RU, ST = Saint Petersburg, L = Saint Petersburg, O = V Kontakte LLC, CN = *.vk.com
# verify return:1
# CONNECTED(00000003)
# ---
# Certificate chain
#  0 s:C = RU, ST = Saint Petersburg, L = Saint Petersburg, O = V Kontakte LLC, CN = *.vk.com
#    i:C = BE, O = GlobalSign nv-sa, CN = GlobalSign ECC OV SSL CA 2018
#    a:PKEY: id-ecPublicKey, 256 (bit); sigalg: ecdsa-with-SHA384
#    v:NotBefore: Feb 14 11:17:01 2024 GMT; NotAfter: Mar  2 11:51:08 2025 GMT
# -----BEGIN CERTIFICATE-----
# MIIFvDCCBUKgAwIBAgIMeaxddCChplDhre6TMAoGCCqGSM49BAMDMFAxCzAJBgNV
# BAYTAkJFMRkwFwYDVQQKExBHbG9iYWxTaWduIG52LXNhMSYwJAYDVQQDEx1HbG9i
# YWxTaWduIEVDQyBPViBTU0wgQ0EgMjAxODAeFw0yNDAyMTQxMTE3MDFaFw0yNTAz
# ...

# %%
# %%bash
#
# openssl s_client -showcerts -connect iz.ru:443
# Out:
# bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# depth=2 OU = GlobalSign Root CA - R3, O = GlobalSign, CN = GlobalSign
# verify return:1
# depth=1 C = BE, O = GlobalSign nv-sa, CN = GlobalSign GCC R3 DV TLS CA 2020
# verify return:1
# depth=0 CN = *.iz.ru
# verify return:1
# CONNECTED(00000003)
# ---
# Certificate chain
#  0 s:CN = *.iz.ru
#    i:C = BE, O = GlobalSign nv-sa, CN = GlobalSign GCC R3 DV TLS CA 2020
#    a:PKEY: rsaEncryption, 2048 (bit); sigalg: RSA-SHA256
#    v:NotBefore: May 31 09:49:24 2023 GMT; NotAfter: Jul  1 09:49:23 2024 GMT
# -----BEGIN CERTIFICATE-----
# MIIGNzCCBR+gAwIBAgIMA+9wq+2CGmj/+XkcMA0GCSqGSIb3DQEBCwUAMFMxCzAJ
# BgNVBAYTAkJFMRkwFwYDVQQKExBHbG9iYWxTaWduIG52LXNhMSkwJwYDVQQDEyBH
# bG9iYWxTaWduIEdDQyBSMyBEViBUTFMgQ0EgMjAyMDAeFw0yMzA1MzEwOTQ5MjRa
# Fw0yNDA3MDEwOTQ5MjNaMBIxEDAOBgNVBAMMByouaXoucnUwggEiMA0GCSqGSIb3
# DQEBAQUAA4IBDwAwggEKAoIBAQDTtDnGSonvkchk0KHpCXTtVzLeTViXLX5M6phX
# ...
